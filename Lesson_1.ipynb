# %% [markdown]
# <a href="https://colab.research.google.com/github/zvyagind/web-python/blob/Lesson_1/Lesson_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###1. Посмотреть документацию к API GitHub, разобраться как вывести список репозиториев для конкретного пользователя, сохранить JSON-вывод в файле *.json.

# %%
import requests
import json

username = 'zvyagind'
token = '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' #токен с правами на чтение public данных
user = str(input('Введите имя пользователя: ')) #ebay
p = int(1)

git_session = requests.Session()
git_session.auth = (username, token)

def repos_url(user, p):
    return f'https://api.github.com/users/{user}/repos?per_page=100&page={str(p)}'

repos = []
while True:
    #print(repos_url(user, p))
    page = json.loads(git_session.get(repos_url(user, p)).text)
    repos.extend(page)
    if len(page)<100:
        break
    p += 1
    
print(f'У пользователя {user} {len(repos)} репозиториев.', '\n')

try:
    for i, repo in enumerate(repos):
        print (i, repo['name'], repo['url'])
except:
    print('ОШИБКА ЗАПРОСА')
    print(git_session.status_code)
    
with open(f'{user}_repos.json', 'w') as outfile:
    json.dump(repos, outfile, indent = 4)
# Out:
# Введите имя пользователя: ebay
# У пользователя ebay 142 репозиториев.
#
# 0 accelerator https://api.github.com/repos/eBay/accelerator
# 1 accelerator-gzutil https://api.github.com/repos/eBay/accelerator-gzutil
# 2 accelerator-project_skeleton https://api.github.com/repos/eBay/accelerator-project_skeleton
# 3 accessibility-ruleset-runner https://api.github.com/repos/eBay/accessibility-ruleset-runner
# 4 AIALib https://api.github.com/repos/eBay/AIALib
# 5 airflow-rest-api-plugin https://api.github.com/repos/eBay/airflow-rest-api-plugin
# 6 akutan https://api.github.com/repos/eBay/akutan
# 7 ambidex https://api.github.com/repos/eBay/ambidex
# 8 arc https://api.github.com/repos/eBay/arc
# 9 AutoOpt https://api.github.com/repos/eBay/AutoOpt
# 10 BarcodeRenderer https://api.github.com/repos/eBay/BarcodeRenderer
# 11 bascomtask https://api.github.com/repos/eBay/bascomtask
# 12 bayesian-belief-networks https://api.github.com/repos/eBay/bayesian-belief-networks
# 13 bonsai https://api.github.com/repos/eBay/bonsai
# 14 browser-telemetry https://api.github.com/repos/eBay/browser-telemetry
# 15 browserslist-config https://api.github.com/repos/eBay/browserslist-config
# 16 bsonpatch https://api.github.com/repos/eBay/bsonpatch
# 17 cassandra-river https://api.github.com/repos/eBay/cassandra-river
# 18 collectbeat https://api.github.com/repos/eBay/collectbeat
# 19 commands-cli https://api.github.com/repos/eBay/commands-cli
# 20 cors-filter https://api.github.com/repos/eBay/cors-filter
# 21 cronus-agent https://api.github.com/repos/eBay/cronus-agent
# 22 crossdomain-xhr https://api.github.com/repos/eBay/crossdomain-xhr
# 23 CustomRippleView https://api.github.com/repos/eBay/CustomRippleView
# 24 DASTProxy https://api.github.com/repos/eBay/DASTProxy
# 25 Design-Grid-Overlay https://api.github.com/repos/eBay/Design-Grid-Overlay
# 26 Eagle https://api.github.com/repos/eBay/Eagle
# 27 EasyConfig https://api.github.com/repos/eBay/EasyConfig
# 28 ebashlib https://api.github.com/repos/eBay/ebashlib
# 29 ebay-font https://api.github.com/repos/eBay/ebay-font
# 30 ebay-items-react-widget https://api.github.com/repos/eBay/ebay-items-react-widget
# 31 ebay-oauth-android-client https://api.github.com/repos/eBay/ebay-oauth-android-client
# 32 ebay-oauth-csharp-client https://api.github.com/repos/eBay/ebay-oauth-csharp-client
# 33 ebay-oauth-java-client https://api.github.com/repos/eBay/ebay-oauth-java-client
# 34 ebay-oauth-nodejs-client https://api.github.com/repos/eBay/ebay-oauth-nodejs-client
# 35 ebay-oauth-python-client https://api.github.com/repos/eBay/ebay-oauth-python-client
# 36 ebay-predict https://api.github.com/repos/eBay/ebay-predict
# 37 ebay.github.com https://api.github.com/repos/eBay/ebay.github.com
# 38 ebayui-core https://api.github.com/repos/eBay/ebayui-core
# 39 ebayui-storybook https://api.github.com/repos/eBay/ebayui-storybook
# 40 EBNObservable https://api.github.com/repos/eBay/EBNObservable
# 41 embedded-druid https://api.github.com/repos/eBay/embedded-druid
# 42 eslint-config-ebay https://api.github.com/repos/eBay/eslint-config-ebay
# 43 event-notification-java-sdk https://api.github.com/repos/eBay/event-notification-java-sdk
# 44 event-notification-nodejs-sdk https://api.github.com/repos/eBay/event-notification-nodejs-sdk
# 45 ExpertmakerAccelerator https://api.github.com/repos/eBay/ExpertmakerAccelerator
# 46 FeedSDK https://api.github.com/repos/eBay/FeedSDK
# 47 FeedSDK-Python https://api.github.com/repos/eBay/FeedSDK-Python
# 48 FGrav https://api.github.com/repos/eBay/FGrav
# 49 firebase-remote-config-monitor https://api.github.com/repos/eBay/firebase-remote-config-monitor
# 50 fluid https://api.github.com/repos/eBay/fluid
# 51 flutter_glove_box https://api.github.com/repos/eBay/flutter_glove_box
# 52 funx https://api.github.com/repos/eBay/funx
# 53 gauntlet https://api.github.com/repos/eBay/gauntlet
# 54 geosense https://api.github.com/repos/eBay/geosense
# 55 go-ovn https://api.github.com/repos/eBay/go-ovn
# 56 gravel https://api.github.com/repos/eBay/gravel
# 57 griffin https://api.github.com/repos/eBay/griffin
# 58 Gringofts https://api.github.com/repos/eBay/Gringofts
# 59 GZinga https://api.github.com/repos/eBay/GZinga
# 60 hadoop-tsdb-connector https://api.github.com/repos/eBay/hadoop-tsdb-connector
# 61 hadrian https://api.github.com/repos/eBay/hadrian
# 62 HeadGazeLib https://api.github.com/repos/eBay/HeadGazeLib
# 63 hpulse https://api.github.com/repos/eBay/hpulse
# 64 id-token-validation https://api.github.com/repos/eBay/id-token-validation
# 65 ie-debug https://api.github.com/repos/eBay/ie-debug
# 66 iwen https://api.github.com/repos/eBay/iwen
# 67 Jenkins-Pipeline-Utils https://api.github.com/repos/eBay/Jenkins-Pipeline-Utils
# 68 json-comparison https://api.github.com/repos/eBay/json-comparison
# 69 jsonex https://api.github.com/repos/eBay/jsonex
# 70 jsonpipe https://api.github.com/repos/eBay/jsonpipe
# 71 Jungle https://api.github.com/repos/eBay/Jungle
# 72 jupyterhub https://api.github.com/repos/eBay/jupyterhub
# 73 KPRN https://api.github.com/repos/eBay/KPRN
# 74 kube-credentials-plugin https://api.github.com/repos/eBay/kube-credentials-plugin
# 75 ldapadmtool https://api.github.com/repos/eBay/ldapadmtool
# 76 lexicalDecimal https://api.github.com/repos/eBay/lexicalDecimal
# 77 libovsdb https://api.github.com/repos/eBay/libovsdb
# 78 lightning https://api.github.com/repos/eBay/lightning
# 79 marko-dynamic-tag https://api.github.com/repos/eBay/marko-dynamic-tag
# 80 marko-playground https://api.github.com/repos/eBay/marko-playground
# 81 maxDNN https://api.github.com/repos/eBay/maxDNN
# 82 Mildly-Rich-Text-Editor https://api.github.com/repos/eBay/Mildly-Rich-Text-Editor
# 83 mindpatterns https://api.github.com/repos/eBay/mindpatterns
# 84 modanet https://api.github.com/repos/eBay/modanet
# 85 modshot https://api.github.com/repos/eBay/modshot
# 86 mtdtool https://api.github.com/repos/eBay/mtdtool
# 87 mTracker https://api.github.com/repos/eBay/mTracker
# 88 myriad https://api.github.com/repos/eBay/myriad
# 89 MySQL-Benchmark-Perl https://api.github.com/repos/eBay/MySQL-Benchmark-Perl
# 90 Neutrino https://api.github.com/repos/eBay/Neutrino
# 91 NMessenger https://api.github.com/repos/eBay/NMessenger
# 92 NococoHint https://api.github.com/repos/eBay/NococoHint
# 93 nodash https://api.github.com/repos/eBay/nodash
# 94 Notebook https://api.github.com/repos/eBay/Notebook
# 95 NuRaft https://api.github.com/repos/eBay/NuRaft
# 96 nvidiagpubeat https://api.github.com/repos/eBay/nvidiagpubeat
# 97 oink https://api.github.com/repos/eBay/oink
# 98 oja https://api.github.com/repos/eBay/oja
# 99 opentracing-basic https://api.github.com/repos/eBay/opentracing-basic
# 100 ostara https://api.github.com/repos/eBay/ostara
# 101 parallec https://api.github.com/repos/eBay/parallec
# 102 parallec-plugins https://api.github.com/repos/eBay/parallec-plugins
# 103 parallec-samples https://api.github.com/repos/eBay/parallec-samples
# 104 Pine https://api.github.com/repos/eBay/Pine
# 105 pynetforce https://api.github.com/repos/eBay/pynetforce
# 106 reactive-source https://api.github.com/repos/eBay/reactive-source
# 107 regressr https://api.github.com/repos/eBay/regressr
# 108 restcommander https://api.github.com/repos/eBay/restcommander
# 109 retriever https://api.github.com/repos/eBay/retriever
# 110 RTran https://api.github.com/repos/eBay/RTran
# 111 Sequence-Semantic-Embedding https://api.github.com/repos/eBay/Sequence-Semantic-Embedding
# 112 ServiceCOLDCache https://api.github.com/repos/eBay/ServiceCOLDCache
# 113 sigir-2019-ecom-challenge https://api.github.com/repos/eBay/sigir-2019-ecom-challenge
# 114 SimbaPipelines https://api.github.com/repos/eBay/SimbaPipelines
# 115 SimpleOPE https://api.github.com/repos/eBay/SimpleOPE
# 116 SketchSVG https://api.github.com/repos/eBay/SketchSVG
# 117 skin https://api.github.com/repos/eBay/skin
# 118 skin-react https://api.github.com/repos/eBay/skin-react
# 119 soar-sec https://api.github.com/repos/eBay/soar-sec
# 120 Spark https://api.github.com/repos/eBay/Spark
# 121 SparkChamber https://api.github.com/repos/eBay/SparkChamber
# 122 splunklogging https://api.github.com/repos/eBay/splunklogging
# 123 storybook-addon-themepicker https://api.github.com/repos/eBay/storybook-addon-themepicker
# 124 SVNetworking https://api.github.com/repos/eBay/SVNetworking
# 125 TargetedAutoRetry https://api.github.com/repos/eBay/TargetedAutoRetry
# 126 taxonomy-sdk https://api.github.com/repos/eBay/taxonomy-sdk
# 127 TDD-Albums https://api.github.com/repos/eBay/TDD-Albums
# 128 TrustFabric https://api.github.com/repos/eBay/TrustFabric
# 129 tsv-utils https://api.github.com/repos/eBay/tsv-utils
# 130 UAF https://api.github.com/repos/eBay/UAF
# 131 userscript-proxy https://api.github.com/repos/eBay/userscript-proxy
# 132 visual-html https://api.github.com/repos/eBay/visual-html
# 133 Vivid https://api.github.com/repos/eBay/Vivid
# 134 WearCrashReporter https://api.github.com/repos/eBay/WearCrashReporter
# 135 web-client-benchmark https://api.github.com/repos/eBay/web-client-benchmark
# 136 WebRex https://api.github.com/repos/eBay/WebRex
# 137 wextracto https://api.github.com/repos/eBay/wextracto
# 138 Winder https://api.github.com/repos/eBay/Winder
# 139 xcelite https://api.github.com/repos/eBay/xcelite
# 140 xeazy https://api.github.com/repos/eBay/xeazy
# 141 YiDB https://api.github.com/repos/eBay/YiDB

# %% [markdown]
# ##2. Изучить список открытых API (https://www.programmableweb.com/category/all/apis). Найти среди них любое, требующее авторизацию (любого типа). Выполнить запросы к нему, пройдя авторизацию. Ответ сервера записать в файл. Если нет желания заморачиваться с поиском, возьмите API вконтакте (https://vk.com/dev/first_guide). Сделайте запрос, чтобы получить список всех сообществ на которые вы подписаны.

# %%
#API Yandex.Translate
#из-за ограничений на суточное кол-во переводов на токен может работать не корректно


import requests
import json

url = 'https://translate.yandex.net/api/v1.5/tr.json/translate'
token = 'trnsl.1.1.20171004T090712Z.bedb9117507053a9.754de6d0f3bb8b79dca22c31f2d4a4816ca8557d'

resp_codes = {200:'Операция выполнена успешно', 
              401:'Неправильный API-ключ',
              402:'API-ключ заблокирован',
              403:'Превышено суточное ограничение на объем переведенного текста',
              404:'Превышено суточное ограничение на объем переведенного текста',
              413:'Превышен максимально допустимый размер текста',
              422:'Текст не может быть переведен',
              501:'Заданное направление перевода не поддерживается'
}

def translate_me(mytext):
    params = {
        "key": token,     
        "text": mytext,
        "lang": 'ru-en'
    }
    response = requests.get(url , params=params)
    return response.json(), response.status_code

txt, resp = translate_me('Введите текст на русском для перевода')

try:
    print(''.join(txt['text']))
except:
    print(resp, resp_codes[resp])
else:
    print(txt['code'], ' ', txt['message'])
# Out:
# 403 Превышено суточное ограничение на объем переведенного текста
